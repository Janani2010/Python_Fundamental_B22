# %%
def greetuser():
    """creating a function to greet the user"""

# %%
print('hello')
greetuser()
# Out:
# hello

# %%
def greetuser(user):
    """creating a function to greet the user"""
    print(f"hello,{user.title()}")
    greetuser('deva')

# %%
greetuser('kala')
# Out:
# hello,Kala
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# hello,Deva
# ...

# %%
def describe_vehicle(v_type,v_color):
    """create the function for vehicle describe"""
    print(f" I have a {v_type}")
    print(f"The color of vehicle is{v_color}")

# %%
describe_vehicle('car','grey')
# Out:
#  I have a car
# The color of vehicle isgrey
